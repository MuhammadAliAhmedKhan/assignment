# %%
a1 = 1.3
b1 = 2.3
sum = a1 + b1
print(f"The Total sum of {a1} and {b1} number is: {sum}")
# Out:
# The Total sum of 1.3 and 2.3 number is: 3.5999999999999996

# %%
num1 = int(input("Enter First Number: "))
num2 = int(input("Enter Second Number: "))
sum = num1 + num2
print(f"The Total sum of {num1} and {num2} number is: {sum}")
# Out:
# Enter First Number: 5
# Enter Second Number: 6
# The Total sum of 5 and 6 number is: 11

# %%
a1 = int(input("Enter Number: "))
sqrt = a1**0.05
print(f"The Total square of {a1} number is: {sqrt}")
# Out:
# Enter Number: 3
# The Total square of 3 number is: 1.056467308549538

# %%
import cmath
num = 1+ 2j
num_sqrt = cmath.sqrt(num)
print(f"The Total square root of {num} number is: {num_sqrt}")
# Out:
# The Total square root of (1+2j) number is: (1.272019649514069+0.7861513777574233j)

# %%
celsius =37.5
fahrenheit = (celsius * 1.8) + 32
print(f"{celsius} degree Celsius is equal to {fahrenheit}")
# Out:
# 37.5 degree Celsius is equal to 99.5

# %%
a = 5
b = 6
c = 7
s = (a + b + c) / 2
area = (s*(s-a)*(s-b)*(s-c)) ** 0.5
print(f"The area of the triangle is {area}")
# Out:
# The area of the triangle is 14.696938456699069

# %%
import cmath
a = 1
b = 5
c = 6
d = (b**2) - (4*a*c)
sol1 = (-b-cmath.sqrt(d))/(2*a)
sol2 = (-b+cmath.sqrt(d))/(2*a)
print(f"The solutions is {sol1} and {sol2}")
# Out:
# The solutions is (-3+0j) and (-2+0j)

# %%
kilometers = float(input("Enter value in kilometers: "))
conv_fac = 0.621371
miles = kilometers * conv_fac
print(f"so the total miles of given:{kilometers} is {miles}")
# Out:
# Enter value in kilometers: 6
# so the total miles of given:6.0 is 3.7282260000000003

# %%
i = int(input("Enter the number: "))
if (i > 15):
  print(f"{i} is greater then 15")
else:
  print(f"{i} is less then 15")
# Out:
# Enter the number: 12
# 12 is less then 15

# %%
i = int(input("Enter the number: "))
if (i > 15):
  print(f"{i} is True")
else:
  print(f"{i} is False")
# Out:
# Enter the number: 10
# 10 is False

# %%
i = 20
if (i == 10):
  print("i is 10")
elif (i == 15):
  print("i is 15")
elif (i == 20):
  print("i is 20")
else:
  print("i is not present")
# Out:
# i is 20

# %%
s = ["Geeks", "for", "Geeks"]

# using for loop with list of strings
for i in s:
    print(i)
# Out:
# Geeks
# for
# Geeks

# %%
count = 0
while count < 3:
    count = count + 1
    print("Hello Geek")
# Out:
# Hello Geek
# Hello Geek
# Hello Geek

# %%
a = [1, 3, 5, 7, 9, 11]
val = 7

for i in a:
    if i == val:
        print(f"Found at {i}!")
        break
else:
    print(f"not found")
# Out:
# Found at 7!

# %%
for i in range(1, 11):
    if i == 6:
        continue
    print(i, end=" ")
# Out:
# 1 2 3 4 5 7 8 9 10

# %%
words = ['The', 'Big', 'Bang', 'Theory']

for index, value in enumerate(words):
    print(index, value)
# Out:
# 0 The
# 1 Big
# 2 Bang
# 3 Theory

# %%
def fun():
    print("Welcome to GFG")

fun()
# Out:
# Welcome to GFG

# %%
# a list of three elements
ages = [19, 26, 29]
print(ages)
# Out:
# [19, 26, 29]

# %%
numbers = (1, 2, -5)
print(numbers)

# Output: (1, 2, -5)
# Out:
# (1, 2, -5)

# %%
# create string type variables

name = "Python"
print(name)

message = "I love Python."
print(message)
# Out:
# Python
# I love Python.

# %%
# create a set of integer type
student_id = {112, 114, 116, 118, 115}
print('Student ID:', student_id)

# create a set of string type
vowel_letters = {'a', 'e', 'i', 'o', 'u'}
print('Vowel Letters:', vowel_letters)

# create a set of mixed data types
mixed_set = {'Hello', 101, -2, 'Bye'}
print('Set of mixed data types:', mixed_set)
# Out:
# Student ID: {112, 114, 115, 116, 118}
# Vowel Letters: {'e', 'a', 'o', 'i', 'u'}
# Set of mixed data types: {'Hello', 101, 'Bye', -2}

# %%
# creating a dictionary
country_capitals = {
  "Germany": "Berlin",
  "Canada": "Ottawa",
  "England": "London"
}

# printing the dictionary
print(country_capitals)
# Out:
# {'Germany': 'Berlin', 'Canada': 'Ottawa', 'England': 'London'}
